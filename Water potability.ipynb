# %%
cd C:\Users\PRASANT\Desktop\Data Science\Datasets
# Out:
# C:\Users\PRASANT\Desktop\Data Science\Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['ph']=df['ph'].replace(np.nan,'7.08')
df['Sulfate']=df['Sulfate'].replace(np.nan,'333.775777')
df['Trihalomethanes']=df['Trihalomethanes'].replace(np.nan,'66.396293')
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   object
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   object
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   object
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 256.1+ KB

# %%
columns=list(df)[0:-1]
df[columns].hist(bins=20,figsize=(14,20))
plt.show()

# %%
X = df.iloc[ : ,0:8].values
y = df.iloc[ : , -1].values

# %%
X
# Out:
# array([['7.08', 204.89045547133634, 20791.318980747023, ...,
#         564.3086541722439, 10.3797830780847, 86.9909704615088],
#        [3.7160800753869903, 129.42292051494422, 18630.05785797035, ...,
#         592.8853591348523, 15.18001311635726, 56.32907628451764],
#        [8.099124189298397, 224.23625939355773, 19909.541732292397, ...,
#         418.6062130644815, 16.868636929550973, 66.42009251176368],
#        ...,
#        [9.419510316413211, 175.76264629629543, 33155.57821831229, ...,
#         432.044783045368, 11.039069688154314, 69.84540029205144],
#        [5.126762923351532, 230.60375750846126, 11983.869376336364, ...,
#         402.883113121781, 11.1689462210565, 77.48821310275477],
#        [7.874671357791282, 195.10229858610904, 17404.17706105066, ...,
#         327.4597604610721, 16.140367626166324, 78.69844632549504]],
#       dtype=object)

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y , test_size=0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
Classifier= DecisionTreeClassifier(criterion='entropy',random_state=0)
Classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(72,27),dpi=150)
plot_tree(Classifier,filled=True)
plt.show()

# %%
y_pred=Classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[337 165]
#  [160 157]]

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(Classifier,X_test,y_test)

# %%
from sklearn.metrics import accuracy_score
print("Test Accuracy",accuracy_score(y_test,y_pred))
# Out:
# Test Accuracy 0.6031746031746031

# %%
y_pred_train=Classifier.predict(X_train)

# %%
print("Train accuracy",accuracy_score(y_train,y_pred_train))
# Out:
# Train accuracy 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.67       502
#            1       0.49      0.50      0.49       317
#
#     accuracy                           0.60       819
#    macro avg       0.58      0.58      0.58       819
# weighted avg       0.60      0.60      0.60       819

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(Classifier,X_test,y_test)
plt.show()

# %%
Classifier.feature_importances_
# Out:
# array([0.12759327, 0.12720973, 0.12695751, 0.15146543, 0.12809434,
#        0.11227548, 0.10343411, 0.12297013])

# %%
from sklearn.ensemble import RandomForestClassifier
Classifier=RandomForestClassifier()
Classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=Classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[442  60]
#  [212 105]]

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(Classifier,X_test,y_test)

# %%
from sklearn.metrics import accuracy_score
print("Test Accuracy",accuracy_score(y_test,y_pred))
# Out:
# Test Accuracy 0.6678876678876678

# %%
y_pred_train=Classifier.predict(X_train)

# %%
print("Train accuracy",accuracy_score(y_train,y_pred_train))
# Out:
# Train accuracy 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.88      0.76       502
#            1       0.64      0.33      0.44       317
#
#     accuracy                           0.67       819
#    macro avg       0.66      0.61      0.60       819
# weighted avg       0.66      0.67      0.64       819

# %%
from sklearn.model_selection import GridSearchCV

param_grid={'n_estimators':[25,50,75,100,200,300,500,1000],'max_features':[1,2,3,4,5,6,7,8]}

rfc=RandomForestClassifier()

grid=GridSearchCV(rfc,param_grid,cv=5,scoring='accuracy')

grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_features': [1, 2, 3, 4, 5, 6, 7, 8],
#                          'n_estimators': [25, 50, 75, 100, 200, 300, 500,
#                                           1000]},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'max_features': 5, 'n_estimators': 300}

# %%
predictions=grid.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.87      0.76       502
#            1       0.61      0.33      0.43       317
#
#     accuracy                           0.66       819
#    macro avg       0.64      0.60      0.59       819
# weighted avg       0.65      0.66      0.63       819

# %%
plot_confusion_matrix(grid,X_test,y_test)

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(grid,X_test,y_test)
plt.show()

# %%
classifier = RandomForestClassifier(n_estimators=300,max_features=5, random_state=0)

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_features=5, n_estimators=300, random_state=0)

# %%
Water_potability= 'finalised_model.sav'

# %%
import joblib 
from joblib import dump,load

# %%
joblib.dump(classifier,Water_potability)
# Out:
# ['finalised_model.sav']
